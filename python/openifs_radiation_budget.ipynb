# %%
import xarray as xr
import os
import pandas as pd
import tqdm
import dask
from dask.delayed import delayed
from dask.diagnostics import ProgressBar
from collections import OrderedDict
from itertools import product
import os
from netCDF4 import Dataset
from cdo import *   # python version
cdo = Cdo()
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import matplotlib.pylab as pylab
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
from itertools import chain

# %%
# parameters cell
input_paths = ['/p/largedata/hhb19/jstreffi/runtime/awicm-3.1/SPIN/outdata/oifs/links/']

input_names = ['SPIN']
climatology_path = ['/p/project/chhb19/streffing1/obs/era5/netcdf/']
accumulation_period = 21600 # output frequency of OpenIFS in seconds
exps = list(range(1, 25)) + list(range(34, 45))
figsize=(7.2, 3.8)
dpi = 300
var = ['SSR', 'STR', 'TSR', 'TTR', 'SLHF', 'SSHF'] 

ofile = "radiation_budget"
#var must have order:  
#1. Surface net solar radiation
#2. Surface net thermal radiation
#3. Top net solar radiation
#4. Top net thermal radiation

# %%
def smooth(x,beta):
    """ kaiser window smoothing """
    window_len=21
    beta=20
    # extending the data at beginning and at the end
    # to apply the window at the borders
    s = np.r_[x[window_len-1:0:-1],x,x[-1:-window_len:-1]]
    w = np.kaiser(window_len,beta)
    y = np.convolve(w/w.sum(),s,mode='valid')
    return y[10:len(y)-10]

# %%
# Load model Data

data = OrderedDict()
for v in var:
    paths = []
    data[v] = []
    for exp in tqdm.tqdm(exps):
        path = input_paths[0]+'/'+v+'_'+f'{exp:05d}.nc'
        data[v].append(cdo.yearmean(input="-fldmean "+str(path),returnArray=v)/accumulation_period)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:45<00:00,  1.29s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:44<00:00,  1.29s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:42<00:00,  1.22s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:47<00:00,  1.34s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:44<00:00,  1.26s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:46<00:00,  1.32s/it]

# %%
surface =   np.squeeze(data['SSR']).flatten() + \
            np.squeeze(data['STR']).flatten() + \
            np.squeeze(data['SSHF']).flatten() + \
            np.squeeze(data['SLHF']).flatten()
toa = np.squeeze(data['TSR']).flatten() + \
      np.squeeze(data['TTR']).flatten()

# %%
fig, axes = plt.subplots(figsize=figsize)

years = range(1850-701, 2550-701)

plt.plot(years,surface,linewidth=0.5,color='darkblue', label='_nolegend_')
plt.plot(years,toa,linewidth=0.5,color='orange', label='_nolegend_')
plt.plot(years,-(toa-surface),linewidth=0.5,color='grey', label='_nolegend_')

plt.plot(years,smooth(surface,len(surface)),color='darkblue')
plt.plot(years,smooth(toa,len(toa)),color='orange')
plt.plot(years,smooth(-(toa-surface),len(toa-surface)),color='grey')

axes.set_title('Radiative balance',fontweight="bold")

plt.axhline(y=0, color='black', linestyle='-')
plt.ylabel('W/m²',size='13')
plt.xlabel('Year',size='13')

plt.axvline(x=1650,color='grey',alpha=0.6)
 


axes2 = axes.twinx()
axes2.set_ylim(axes.get_ylim())

axes.xaxis.set_minor_locator(MultipleLocator(10))
axes.yaxis.set_minor_locator(MultipleLocator(0.2))
axes2.yaxis.set_minor_locator(MultipleLocator(0.2))

axes.tick_params(labelsize='12')
axes2.tick_params(labelsize='12')

axes.legend(['Net SFC', 'Net TOA', '\u0394(SFC - TOA)'],fontsize=11)
plt.tight_layout()

if ofile is not None:
    plt.savefig(ofile, dpi=dpi,bbox_inches='tight')
    os.system(f'convert {ofile} -trim {ofile}_trimmed.png')
    os.system(f'mv {ofile}_trimmed.png {ofile}')
# Out:
# convert: unable to open image 'radiation_budget': No such file or directory @ error/blob.c/OpenBlob/3533.
# convert: no decode delegate for this image format `' @ error/constitute.c/ReadImage/572.
# convert: no images defined `radiation_budget_trimmed.png' @ error/convert.c/ConvertImageCommand/3322.
# mv: cannot stat 'radiation_budget_trimmed.png': No such file or directory
